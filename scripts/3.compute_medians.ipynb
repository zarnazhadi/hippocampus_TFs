# %%
import os
import pandas as pd
import numpy as np

# import csv file
dat = pd.read_csv("/Users/zarnazhadi/Desktop/hippocampus_TFs/expression_data/10_TFs_expression_data.csv", sep= ',', header=0) # change working directory

# %%
del dat['sample'] # delete sample column

# %%
dat
# Out:
#       DDX11L1  WASH7P  MIR6859-1  MIR1302-2HG  FAM138A   OR4G4P  OR4G11P  \
# 0     0.01776   6.892     0.0000      0.00000  0.00000  0.03656  0.03267
# 1     0.00000   4.225     0.4912      0.07713  0.00000  0.00000  0.10660
# 2     0.00000   7.778     0.7710      0.00000  0.00000  0.00000  0.00000
# 3     0.01709   2.359     0.0000      0.03413  0.02424  0.03518  0.12580
# 4     0.00000   8.939     0.0000      0.00000  0.00000  0.00000  0.11430
# ...       ...     ...        ...          ...      ...      ...      ...
# 2637  0.00000   2.314     0.0000      0.03735  0.00000  0.00000  0.10320
# 2638  0.02613   5.511     0.0000      0.10430  0.00000  0.00000  0.09613
# 2639  0.00000   4.305     0.0000      0.04682  0.00000  0.00000  0.00000
# 2640  0.03126   3.907     0.0000      0.00000  0.00000  0.00000  0.11500
# 2641  0.01874   2.123     0.0000      0.00000  0.00000  0.03857  0.10340
#
#         OR4F5  RP11-34P13.7   CICP27  tissue_type
# 0     0.10040       0.02986  0.00000      Cortex
# 1     0.03638       0.03247  0.02894      Cortex
# 2     0.05711       0.02549  0.04543  Cerebellum
# 3     0.03219       0.00000  0.00000      Cortex
# 4     0.05851       0.02611  0.04655  Cerebellum
# ...       ...           ...      ...          ...
# 2637  0.07047       0.01572  0.00000      Cortex
# 2638  0.00000       0.08785  0.07830  Cerebellum
# 2639  0.00000       0.03943  0.05856      Cortex
# 2640  0.00000       0.02627  0.01561  Cerebellum
# 2641  0.00000       0.01575  0.01872      Cortex
#
# [2642 rows x 11 columns]

# %%
medians = dat.groupby(['tissue_type']).median() # median
means= dat.groupby(['tissue_type']).mean() # mean

# %%
medians = medians.transpose() # formatting

# %%
# make new comparison table by subsetting medians with only hippocampus

comparison = pd.DataFrame(medians['Hippocampus '])
only_true = pd.DataFrame(medians['Hippocampus '])

# compute difference for each column from hippocampus- with true/false and hippocampus-median of other tissue

for column in medians.columns:
    if column != 'Hippocampus ':
        
        # find out if median is larger than hippocampus median
        colname1 = column + " > Hippocampus"
        comparison[colname1]  =medians.apply(lambda  x: True if x[column] > x['Hippocampus '] else False ,axis=1)
        
        # compute difference between the two
        colname2 = column + " - Hippocampus"
        comparison[colname2]  =medians.apply(lambda  x: x[column] - x['Hippocampus '],axis=1)
        # print(comparison.sort_values(colname2))
        
        # rank
        #colname3 = column + " rank"
        #comparison[colname3] = comparison[colname2].rank(ascending= False).astype(int)

# %%
comparison
# Out:
#               Hippocampus   Amygdala  > Hippocampus  Amygdala  - Hippocampus  \
# DDX11L1            0.00000                    False                 0.000000
# WASH7P             1.68600                    False                -0.247500
# MIR6859-1          0.00000                    False                 0.000000
# MIR1302-2HG        0.00000                    False                 0.000000
# FAM138A            0.00000                    False                 0.000000
# OR4G4P             0.05291                    False                -0.003235
# OR4G11P            0.07750                    False                -0.013670
# OR4F5              0.10310                    False                -0.024230
# RP11-34P13.7       0.02006                    False                -0.001015
# CICP27             0.01371                     True                 0.000975
#
#               Anterior cingulate cortex (BA24)  > Hippocampus  \
# DDX11L1                                                 False
# WASH7P                                                   True
# MIR6859-1                                               False
# MIR1302-2HG                                             False
# FAM138A                                                 False
# OR4G4P                                                   True
# OR4G11P                                                 False
# OR4F5                                                   False
# RP11-34P13.7                                             True
# CICP27                                                   True
#
#               Anterior cingulate cortex (BA24)  - Hippocampus  \
# DDX11L1                                              0.000000
# WASH7P                                               0.007000
# MIR6859-1                                            0.000000
# MIR1302-2HG                                          0.000000
# FAM138A                                              0.000000
# OR4G4P                                               0.000625
# OR4G11P                                             -0.009550
# OR4F5                                               -0.026380
# RP11-34P13.7                                         0.000715
# CICP27                                               0.003795
#
#               Caudate (basal ganglia)  > Hippocampus  \
# DDX11L1                                        False
# WASH7P                                         False
# MIR6859-1                                      False
# MIR1302-2HG                                     True
# FAM138A                                        False
# OR4G4P                                         False
# OR4G11P                                        False
# OR4F5                                          False
# RP11-34P13.7                                   False
# CICP27                                          True
#
#               Caudate (basal ganglia)  - Hippocampus  \
# DDX11L1                                     0.000000
# WASH7P                                     -0.120000
# MIR6859-1                                   0.000000
# MIR1302-2HG                                 0.024265
# FAM138A                                     0.000000
# OR4G4P                                     -0.007340
# OR4G11P                                    -0.005460
# OR4F5                                      -0.020430
# RP11-34P13.7                               -0.001520
# CICP27                                      0.004075
#
#               Cerebellar Hemisphere  > Hippocampus  \
# DDX11L1                                      False
# WASH7P                                        True
# MIR6859-1                                    False
# MIR1302-2HG                                  False
# FAM138A                                      False
# OR4G4P                                       False
# OR4G11P                                      False
# OR4F5                                        False
# RP11-34P13.7                                  True
# CICP27                                        True
#
#               Cerebellar Hemisphere  - Hippocampus  Cerebellum  > Hippocampus  \
# DDX11L1                                    0.00000                      False
# WASH7P                                     3.30600                       True
# MIR6859-1                                  0.00000                      False
# MIR1302-2HG                                0.00000                      False
# FAM138A                                    0.00000                      False
# OR4G4P                                    -0.02827                      False
# OR4G11P                                   -0.03064                      False
# OR4F5                                     -0.04324                      False
# RP11-34P13.7                               0.00223                       True
# CICP27                                     0.01573                       True
#
#               ...  Hypothalamus  > Hippocampus  Hypothalamus  - Hippocampus  \
# DDX11L1       ...                        False                     0.000000
# WASH7P        ...                         True                     0.062000
# MIR6859-1     ...                        False                     0.000000
# MIR1302-2HG   ...                         True                     0.024715
# FAM138A       ...                        False                     0.000000
# OR4G4P        ...                        False                    -0.013245
# OR4G11P       ...                        False                    -0.013525
# OR4F5         ...                        False                    -0.019960
# RP11-34P13.7  ...                        False                    -0.000765
# CICP27        ...                         True                     0.010205
#
#               Nucleus accumbens (basal ganglia)  > Hippocampus  \
# DDX11L1                                                  False
# WASH7P                                                   False
# MIR6859-1                                                False
# MIR1302-2HG                                               True
# FAM138A                                                  False
# OR4G4P                                                   False
# OR4G11P                                                  False
# OR4F5                                                    False
# RP11-34P13.7                                             False
# CICP27                                                    True
#
#               Nucleus accumbens (basal ganglia)  - Hippocampus  \
# DDX11L1                                               0.000000
# WASH7P                                               -0.147000
# MIR6859-1                                             0.000000
# MIR1302-2HG                                           0.030670
# FAM138A                                               0.000000
# OR4G4P                                               -0.008400
# OR4G11P                                              -0.018205
# OR4F5                                                -0.021620
# RP11-34P13.7                                         -0.000055
# CICP27                                                0.008215
#
#               Putamen (basal ganglia)  > Hippocampus  \
# DDX11L1                                        False
# WASH7P                                         False
# MIR6859-1                                      False
# MIR1302-2HG                                     True
# FAM138A                                        False
# OR4G4P                                         False
# OR4G11P                                        False
# OR4F5                                          False
# RP11-34P13.7                                   False
# CICP27                                          True
#
#               Putamen (basal ganglia)  - Hippocampus  \
# DDX11L1                                      0.00000
# WASH7P                                      -0.24400
# MIR6859-1                                    0.00000
# MIR1302-2HG                                  0.02347
# FAM138A                                      0.00000
# OR4G4P                                      -0.00442
# OR4G11P                                     -0.01253
# OR4F5                                       -0.00460
# RP11-34P13.7                                -0.00360
# CICP27                                       0.00156
#
#               Spinal cord (cervical c-1)  > Hippocampus  \
# DDX11L1                                           False
# WASH7P                                             True
# MIR6859-1                                         False
# MIR1302-2HG                                       False
# FAM138A                                           False
# OR4G4P                                            False
# OR4G11P                                           False
# OR4F5                                             False
# RP11-34P13.7                                      False
# CICP27                                             True
#
#               Spinal cord (cervical c-1)  - Hippocampus  \
# DDX11L1                                         0.00000
# WASH7P                                          1.04400
# MIR6859-1                                       0.00000
# MIR1302-2HG                                     0.00000
# FAM138A                                         0.00000
# OR4G4P                                         -0.01131
# OR4G11P                                        -0.02038
# OR4F5                                          -0.03235
# RP11-34P13.7                                   -0.00258
# CICP27                                          0.01065
#
#               Substantia nigra  > Hippocampus  Substantia nigra  - Hippocampus
# DDX11L1                                 False                          0.00000
# WASH7P                                   True                          0.05600
# MIR6859-1                               False                          0.00000
# MIR1302-2HG                              True                          0.01953
# FAM138A                                 False                          0.00000
# OR4G4P                                  False                         -0.00621
# OR4G11P                                 False                         -0.01104
# OR4F5                                   False                         -0.02991
# RP11-34P13.7                            False                         -0.00095
# CICP27                                   True                          0.00195
#
# [10 rows x 25 columns]

# %%
# comparison_copy = comparison.copy(deep = True)
value = comparison.values
tf = comparison.index
tissue = comparison.columns

#  Get indices where such threshold is crossed; avoid diagonal elems
R,C = np.where(np.triu(value,1)>0)

# Arrange those in columns and put out as a dataframe
out_value = np.column_stack((tf[R],tissue[C],value[R,C]))
only_true = pd.DataFrame(out_value,columns=[['tf','col_name','value']])
only_true.columns = ['tf', 'tissue-hippocampus', 'value']

# %%
only_true['rank'] = only_true['value'].rank(ascending=False).astype(int)

# %%
only_true
# Out:
#              tf                                tissue-hippocampus     value  \
# 0        WASH7P   Anterior cingulate cortex (BA24)  - Hippocampus     0.007
# 1        WASH7P              Cerebellar Hemisphere  - Hippocampus     3.306
# 2        WASH7P                         Cerebellum  - Hippocampus     4.035
# 3        WASH7P                             Cortex  - Hippocampus     0.797
# 4        WASH7P               Frontal Cortex (BA9)  - Hippocampus     0.461
# 5        WASH7P                       Hypothalamus  - Hippocampus     0.062
# 6        WASH7P         Spinal cord (cervical c-1)  - Hippocampus     1.044
# 7        WASH7P                   Substantia nigra  - Hippocampus     0.056
# 8   MIR1302-2HG                             Cortex  - Hippocampus   0.02737
# 9   MIR1302-2HG               Frontal Cortex (BA9)  - Hippocampus   0.03038
# 10  MIR1302-2HG                       Hypothalamus  - Hippocampus  0.024715
# 11  MIR1302-2HG  Nucleus accumbens (basal ganglia)  - Hippocampus   0.03067
# 12  MIR1302-2HG            Putamen (basal ganglia)  - Hippocampus   0.02347
# 13  MIR1302-2HG                   Substantia nigra  - Hippocampus   0.01953
# 14       CICP27            Putamen (basal ganglia)  - Hippocampus   0.00156
# 15       CICP27         Spinal cord (cervical c-1)  - Hippocampus   0.01065
# 16       CICP27                   Substantia nigra  - Hippocampus   0.00195
#
#     rank
# 0     15
# 1      2
# 2      1
# 3      4
# 4      5
# 5      6
# 6      3
# 7      7
# 8     10
# 9      9
# 10    11
# 11     8
# 12    12
# 13    13
# 14    17
# 15    14
# 16    16
